# %%
import pandas as pd
ratings=pd.read_csv('/content/Ratings.csv',encoding="latin-1",delimiter=",")
ratings
# Out:
#          User-ID         ISBN  Book-Rating
# 0         276725   034545104X            0
# 1         276726   0155061224            5
# 2         276727   0446520802            0
# 3         276729   052165615X            3
# 4         276729   0521795028            6
# ...          ...          ...          ...
# 1149775   276704   1563526298            9
# 1149776   276706   0679447156            0
# 1149777   276709   0515107662           10
# 1149778   276721   0590442449           10
# 1149779   276723  05162443314            8
#
# [1149780 rows x 3 columns]

# %%
books=pd.read_csv('/content/Books.csv',encoding="latin-1",delimiter=",")
books
# Out:
# <ipython-input-6-ce6c4ff5b473>:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books=pd.read_csv('/content/Books.csv',encoding="latin-1",delimiter=",")
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# ...

# %%
ratings_books=pd.merge(ratings,books,on="ISBN")
ratings_books.shape
# Out:
# (1031136, 10)

# %%
ratings_books
# Out:
#          User-ID        ISBN  Book-Rating  \
# 0         276725  034545104X            0
# 1           2313  034545104X            5
# 2           6543  034545104X            0
# 3           8680  034545104X            5
# 4          10314  034545104X            9
# ...          ...         ...          ...
# 1031131   276688  0517145553            0
# 1031132   276688  1575660792            7
# 1031133   276690  0590907301            0
# 1031134   276704  0679752714            0
# 1031135   276704  0806917695            5
#
#                                                 Book-Title      Book-Author  \
# 0                                     Flesh Tones: A Novel       M. J. Rose
# 1                                     Flesh Tones: A Novel       M. J. Rose
# 2                                     Flesh Tones: A Novel       M. J. Rose
# 3                                     Flesh Tones: A Novel       M. J. Rose
# ...

# %%
ratings.shape
# Out:
# (1149780, 3)

# %%
books.shape
# Out:
# (271360, 8)

# %%
ratings_books_sample=ratings_books.sample(frac=0.01,random_state=1)
ratings_books_sample.shape
# Out:
# (10311, 10)

# %%
ratings_books_sample
# Out:
#          User-ID        ISBN  Book-Rating  \
# 306740    176597  0061006629            6
# 56511     261829  0441172717            0
# 263161    126026  0425136191            7
# 147012    107957  042516313X            0
# 644608     30276  0821762982            8
# ...          ...         ...          ...
# 45560     120908  0140621792            0
# 1016337   250695  0805061746            0
# 519761     73394  0452285186            0
# 570375    182085  0689843372            0
# 128091    144255  0446604666            9
#
#                                                 Book-Title       Book-Author  \
# 306740                                          Fatherland     Robert Harris
# 56511                          Dune (Remembering Tomorrow)     Frank Herbert
# 263161                                          Blindsight        Robin Cook
# 147012                                   Breathing Lessons        Anne Tyler
# ...

# %%
ratings_books_pivot=ratings_books_sample.pivot_table(index='Book-Title',columns='User-ID',values='Book-Rating').fillna(0)
ratings_books_pivot
# Out:
# User-ID                                             254     432     507     \
# Book-Title
#  Garfield Bigger and Better (Garfield (Numbered...     0.0     0.0     0.0
#  Good Wives: Image and Reality in the Lives of ...     0.0     0.0     0.0
#  Little Comic Shop of Horrors (Give Yourself Go...     0.0     0.0     0.0
#  Summonings: Books of Magic, Vol. 2                    0.0     0.0     0.0
# ' Mein verwundetes Herz'. Das Leben der Lilli J...     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
# \You're Okay, It's Just a Bruise\": A Doctor's ...     0.0     0.0     0.0
# \\"N\"\" Is for Noose (Thorndike Large Print Ge...     0.0     0.0     0.0
# e                                                      0.0     0.0     0.0
# Ã?Ã?ber die Pflicht zum Ungehorsam gegen den ...     0.0     0.0     0.0
#
# ...

# %%
from sklearn.neighbors import NearestNeighbors
model=NearestNeighbors(metric='cosine',algorithm='brute',n_neighbors=7,n_jobs=-1)
model.fit(ratings_books_pivot)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine', n_jobs=-1, n_neighbors=7)

# %%
indices=model.kneighbors(ratings_books_pivot.loc[['10 Steps in Writing the Research Paper (10 Steps in Writing the Research Paper, 5th ed)']],10,return_distance=False)
indices
# Out:
# array([[4765,    8, 1667,  539, 8020, 5689, 5690, 5687, 5692, 5688]])

# %%
for index,value in enumerate(ratings_books_pivot.index[indices.flatten()]):
    print((index+1),".",value)
# Out:
# 1 . Pearl in the Mist (Landry)
# 2 . 10 Steps in Writing the Research Paper (10 Steps in Writing the Research Paper, 5th ed)
# 3 . Dealing with People You Can't Stand: How to Bring Out the Best in People at Their Worst
# 4 . Anxiety, Phobias, &amp; Panic : A Step-by-Step Program for Regaining Control of Your Life
# 5 . Unfinished Symphony (Logan)
# 6 . Sosa : An Autobiography
# 7 . Soul Among Lions: The Cougar As Peaceful Adversary
# 8 . Sorcerer's Son
# 9 . Soul Survivor
# 10 . Sorceress of Darshiva (Malloreon (Paperback Random House))
